# %% [markdown]
# # DVA HW4 Q1
# ## Pagerank Algorithm
#
# Do not distribute or publish this code
# Do not change the `#export` statements or add and other code or comments above them. They are needed for grading.

# %%
#export
'''
*** Imports ***
    DO NOT EDIT or add anything to this section
'''
import numpy as np
import time
import argparse
import sys

# %% [markdown]
# ### Update your GT username and Id

# %%
#export
def author():                                                                                             
        return "nanyanwu3"      # replace gburdell3 with your Georgia Tech username.                                                                                             
                                                                                              
def gtid():                                                                                               
    return 902825017            # replace with your GT ID number (https://registrar.gatech.edu/info/gtid-lookup)

# %%
'''
*** Utility function ***
    DO NOT EDIT
'''
def dump_results(command, iterations, result):
    print("Sorting...", file=sys.stderr)
    sorted_result = sorted(enumerate(result), key=lambda x: x[1], reverse=True)
    output_result = "node_id\tpr_value\n"
    for node_id, pr_value in sorted_result[:10]:
        output_result += "{0}\t{1}\n".format(node_id, pr_value)
    print(output_result)

    with open(command+'_iter'+str(iterations)+".txt","w") as output_file:
        output_file.write(output_result)

# %% [markdown]
# ### PageRank Class
# Please add your code as indicated below
# You do not need to add code outside of the indicated areas

# %%
#export
class PageRank:
    def __init__(self, edge_file):
        self.node_degree = {}
        self.max_node_id = 0
        self.edge_file = edge_file

    def read_edge_file(self, edge_file):
        with open(edge_file) as f:
            for line in f:
                val = line.split('\t')
                yield int(val[0]), int(val[1])

    def calculate_node_degree(self):
        for source, target in self.read_edge_file(self.edge_file):
            if source in self.node_degree:
                self.node_degree[source] += 1
            else:
                self.node_degree[source] = 1
            if target not in self.node_degree:
                self.node_degree[target] = 0
            self.max_node_id = max(self.max_node_id, source, target)
        print("Max node id: {}".format(self.max_node_id))
        print("Total source number: {}".format(len(self.node_degree)))

    def get_max_node_id(self):
        return self.max_node_id

    def run_pagerank(self, node_weights, damping_factor=0.85, iterations=10):
        num_nodes = self.max_node_id + 1
        pr = list(node_weights)
        start_time = time.time()

        for it in range(iterations):
            new_pr = [(1 - damping_factor) * node_weights[i] for i in range(num_nodes)]
            d_mass = 0.0

            # Accumulate dangling mass (for nodes with no out-links)
            for i in range(num_nodes):
                if self.node_degree.get(i, 0) == 0:
                    d_mass += pr[i]

            # Distribute PageRank from source to target
            for source, target in self.read_edge_file(self.edge_file):
                if self.node_degree[source] > 0:
                    new_pr[target] += damping_factor * pr[source] / self.node_degree[source]

            # Distribute dangling mass evenly
            dangling_share = damping_factor * d_mass / num_nodes
            new_pr = [val + dangling_share for val in new_pr]

            # Normalize (optional but helps prevent floating point drift)
            total_pr = sum(new_pr)
            pr = [val / total_pr for val in new_pr]

            print("Completed {0}/{1} iterations. {2:.2f} seconds elapsed.".format(it + 1, iterations, time.time() - start_time))

        self.pr_values = pr
        return pr

# %% [markdown]
# ### Simplified Pagerank

# %%
# Options
file = 'network.tsv'                # Input file of the edge list - DO NOT EDIT
command = 'simplified_pagerank'     # Command to run - DO NOT EDIT
damping_factor = 0.85               # Damping factor - submit results for damping_factor = 0.85
iterations = [10,25]                # Number of iterations - sumbit results for iterations = [10,25] 

# Run Simplified PageRank
# DO NOT EDIT
for i in iterations:
    pr = PageRank(file)
    pr.calculate_node_degree()
    max_node_id = pr.get_max_node_id()
    node_weights = np.ones(max_node_id + 1) / (max_node_id + 1)
    result = pr.run_pagerank(node_weights=node_weights, iterations=i, damping_factor=damping_factor)
    dump_results(command, i, result )
# Out:
# Max node id: 1157826
# Total source number: 1134890
# Completed 1/10 iterations. 3.62 seconds elapsed.
# Completed 2/10 iterations. 7.39 seconds elapsed.
# Completed 3/10 iterations. 10.91 seconds elapsed.
# Completed 4/10 iterations. 14.35 seconds elapsed.
# Completed 5/10 iterations. 17.89 seconds elapsed.
# Completed 6/10 iterations. 21.35 seconds elapsed.
# Completed 7/10 iterations. 25.06 seconds elapsed.
# Completed 8/10 iterations. 28.75 seconds elapsed.
# Completed 9/10 iterations. 32.32 seconds elapsed.
# Completed 10/10 iterations. 35.87 seconds elapsed.
# Sorting...
# node_id	pr_value
# 663930	0.000787937075031135
# 482708	0.0004299403466297536
# 1034017	0.00025035371172196514
# 663559	0.00022274354220671672
# 357530	0.00020843429438814195
# 1120567	0.00020492494792873352
# 663605	0.00019868862280399775
# 663682	0.00016721369709311117
# 1108860	0.0001610812567632829
# 664788	0.00016009136969908264
#
# Max node id: 1157826
# Total source number: 1134890
# Completed 1/25 iterations. 3.39 seconds elapsed.
# Completed 2/25 iterations. 6.75 seconds elapsed.
# Completed 3/25 iterations. 10.11 seconds elapsed.
# Completed 4/25 iterations. 13.72 seconds elapsed.
# Completed 5/25 iterations. 17.14 seconds elapsed.
# Completed 6/25 iterations. 20.52 seconds elapsed.
# Completed 7/25 iterations. 23.96 seconds elapsed.
# Completed 8/25 iterations. 27.38 seconds elapsed.
# Completed 9/25 iterations. 31.01 seconds elapsed.
# Completed 10/25 iterations. 34.56 seconds elapsed.
# Completed 11/25 iterations. 38.01 seconds elapsed.
# Completed 12/25 iterations. 41.64 seconds elapsed.
# Completed 13/25 iterations. 45.08 seconds elapsed.
# Completed 14/25 iterations. 48.55 seconds elapsed.
# Completed 15/25 iterations. 51.95 seconds elapsed.
# Completed 16/25 iterations. 55.37 seconds elapsed.
# Completed 17/25 iterations. 58.91 seconds elapsed.
# Completed 18/25 iterations. 62.39 seconds elapsed.
# Completed 19/25 iterations. 65.78 seconds elapsed.
# Completed 20/25 iterations. 69.19 seconds elapsed.
# Completed 21/25 iterations. 72.61 seconds elapsed.
# Completed 22/25 iterations. 76.00 seconds elapsed.
# Completed 23/25 iterations. 79.46 seconds elapsed.
# Completed 24/25 iterations. 82.85 seconds elapsed.
# Completed 25/25 iterations. 86.35 seconds elapsed.
# Sorting...
# node_id	pr_value
# 663930	0.0007879383403682299
# 482708	0.00042994073433987636
# 1034017	0.00025035393207452166
# 663559	0.00022274378331838424
# 357530	0.00020843453976118536
# 1120567	0.0002049238150258425
# 663605	0.00019868891554088104
# 663682	0.00016721372187530523
# 1108860	0.00016107906899680987
# 664788	0.00016009163616939799

# %% [markdown]
# ### Personalized Pagerank

# %%
# Options
file = 'network.tsv'                # Input file of the edge list - DO NOT EDIT
command = 'personalized_pagerank'   # Command to run - DO NOT EDIT
damping_factor = 0.85               # Damping factor - submit results for damping_factor = 0.85
iterations = [10,25]                # Number of iterations - sumbit results for iterations = [10,25] 

# Run Personalized PageRank
# DO NOT EDIT
for i in iterations:
    pr = PageRank(file)
    pr.calculate_node_degree()
    max_node_id = pr.get_max_node_id()
    np.random.seed(gtid())
    node_weights = np.random.rand(max_node_id + 1)
    node_weights = node_weights/node_weights.sum()
    result = pr.run_pagerank(node_weights=node_weights, iterations=i, damping_factor=damping_factor)
    dump_results(command, i, result)
# Out:
# Max node id: 1157826
# Total source number: 1134890
# Completed 1/10 iterations. 3.56 seconds elapsed.
# Completed 2/10 iterations. 7.02 seconds elapsed.
# Completed 3/10 iterations. 10.44 seconds elapsed.
# Completed 4/10 iterations. 14.02 seconds elapsed.
# Completed 5/10 iterations. 17.56 seconds elapsed.
# Completed 6/10 iterations. 21.13 seconds elapsed.
# Completed 7/10 iterations. 24.75 seconds elapsed.
# Completed 8/10 iterations. 28.35 seconds elapsed.
# Completed 9/10 iterations. 31.85 seconds elapsed.
# Completed 10/10 iterations. 35.40 seconds elapsed.
# Sorting...
# node_id	pr_value
# 663930	0.000787507197970257
# 482708	0.00042978050013857486
# 1034017	0.00025129919303584726
# 663559	0.00022319415078013124
# 357530	0.00020953440716288914
# 1120567	0.00020339062117897646
# 663605	0.00019786497973178885
# 663682	0.0001670485914406783
# 1108860	0.000162235853279287
# 664788	0.00016057294186059816
#
# Max node id: 1157826
# Total source number: 1134890
# Completed 1/25 iterations. 3.54 seconds elapsed.
# Completed 2/25 iterations. 7.07 seconds elapsed.
# Completed 3/25 iterations. 10.56 seconds elapsed.
# Completed 4/25 iterations. 14.17 seconds elapsed.
# Completed 5/25 iterations. 17.69 seconds elapsed.
# Completed 6/25 iterations. 21.22 seconds elapsed.
# Completed 7/25 iterations. 24.73 seconds elapsed.
# Completed 8/25 iterations. 28.23 seconds elapsed.
# Completed 9/25 iterations. 31.84 seconds elapsed.
# Completed 10/25 iterations. 35.33 seconds elapsed.
# Completed 11/25 iterations. 38.82 seconds elapsed.
# Completed 12/25 iterations. 42.33 seconds elapsed.
# Completed 13/25 iterations. 45.88 seconds elapsed.
# Completed 14/25 iterations. 49.47 seconds elapsed.
# Completed 15/25 iterations. 53.06 seconds elapsed.
# Completed 16/25 iterations. 56.73 seconds elapsed.
# Completed 17/25 iterations. 60.37 seconds elapsed.
# Completed 18/25 iterations. 63.99 seconds elapsed.
# Completed 19/25 iterations. 67.82 seconds elapsed.
# Completed 20/25 iterations. 71.43 seconds elapsed.
# Completed 21/25 iterations. 74.95 seconds elapsed.
# Completed 22/25 iterations. 78.49 seconds elapsed.
# Completed 23/25 iterations. 81.95 seconds elapsed.
# Completed 24/25 iterations. 85.54 seconds elapsed.
# Completed 25/25 iterations. 89.04 seconds elapsed.
# Sorting...
# node_id	pr_value
# 663930	0.0007875085066854961
# 482708	0.000429780899991464
# 1034017	0.0002512994272767598
# 663559	0.00022319439976307918
# 357530	0.00020953466071852185
# 1120567	0.00020338939476270576
# 663605	0.00019786528105239252
# 663682	0.00016704861480570758
# 1108860	0.00016223370920806575
# 664788	0.0001605732141198034

# %% [markdown]
# ### Submitting your results to gradescope
# Submit the following on Gradescope
# * Q1.ipynb
# * simplified_pagerank_iter10.txt
# * simplified_pagerank_iter25.txt
# * personalized_pagerank_iter10.txt
# * personalized_pagerank_iter25.txt
